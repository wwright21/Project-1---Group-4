# %%
# import dependencies
import pandas as pd

# %%
# Create 8 dataframes, one for each .csv file
df1 = pd.read_csv('2018_01_01 to 2018_02_28.csv')
df2 = pd.read_csv('2018_03_01 to 2018_09_30.csv')
df3 = pd.read_csv('2018_10_01 to 2019_05_31.csv')
df4 = pd.read_csv('2019_06_01 to 2019_12_31.csv')
df5 = pd.read_csv('2020_01_01 to 2020_07_31.csv')
df6 = pd.read_csv('2020_08_01 to 2021_02_28.csv')
df7 = pd.read_csv('2021_03_01 to 2021_08_31.csv')
df8 = pd.read_csv('2021_09_01 to 2022_04_20.csv')

# %%
# Create a list of our 8 dataframes
df_list = [df1, df2, df3, df4, df5, df6, df7, df8]

# %%
master_data
# Out:
#         County Status        Area                 Sub         City  \
# 0     Cherokee   Sold  113 - CHK3  Longleaf Woodstock    Woodstock
# 1     Cherokee   Sold  113 - CHK3                None       Canton
# 2     Cherokee   Sold  113 - CHK3                None       Canton
# 3     Cherokee   Sold  113 - CHK3          Twin Lakes    Woodstock
# 4     Cherokee   Sold  113 - CHK3    Cherokee Reserve       Canton
# ...        ...    ...         ...                 ...          ...
# 2706  Cherokee   Sold  111 - CHK1  Riverstone Commons       Canton
# 2707  Cherokee   Sold  111 - CHK1      Mountain Brook    Woodstock
# 2708  Cherokee   Sold  113 - CHK3          Bellehaven    Woodstock
# 2709  Cherokee   Sold  112 - CHK2        Lantern Walk  Ball Ground
# 2710  Cherokee   Sold  112 - CHK2    Townview Commons    Woodstock
#
#      Postal Code  Sold Price     OLP  List Price   Price  ...  Baths Half  \
# 0          30188      499957  475900      475900  499957  ...           0
# 1     30115-7057      575000  600000      600000  575000  ...           1
# 2     30115-6577      130600  155000      149900  130600  ...           1
# 3          30188      320000  350000      325000  320000  ...           1
# 4     30115-4760      305000  310000      305000  305000  ...           0
# ...          ...         ...     ...         ...     ...  ...         ...
# 2706       30114      255000  255000      255000  255000  ...           1
# 2707       30188      351200  348100      348100  351200  ...           1
# 2708       30188      417500  380000      380000  417500  ...           1
# 2709       30107      292000  290000      290000  292000  ...           2
# 2710       30189      336500  317840      317840  336500  ...           1
#
#       Structure Property Type         Property Subtype   OnMktDate  \
# 0           NaN   Residential  Single Family Residence  10/20/2017
# 1           NaN   Residential  Single Family Residence   10/9/2017
# 2           NaN   Residential  Single Family Residence   11/3/2017
# 3           NaN   Residential  Single Family Residence    9/7/2017
# 4           NaN   Residential  Single Family Residence   9/14/2017
# ...         ...           ...                      ...         ...
# 2706      House   Residential                Townhouse   1/13/2022
# 2707      Other   Residential                Townhouse   2/17/2022
# 2708      Other   Residential                Townhouse   3/10/2022
# 2709      House   Residential                Townhouse   3/10/2022
# 2710      House   Residential                Townhouse   3/11/2022
#
#              OMD  Clsd Date                       Elem Schl Middle Schl  \
# 0      11/2/2017  2/28/2018  Little River Primary/Elementar  Mill Creek
# 1     11/26/2017   1/5/2018                           Avery   Creekland
# 2       1/5/2018  1/30/2018                           Avery   Creekland
# 3     11/16/2017   1/3/2018                   Mountain Road   Dean Rusk
# 4      1/18/2018  2/27/2018                    Hickory Flat   Dean Rusk
# ...          ...        ...                             ...         ...
# 2706   1/13/2022  2/28/2022                       R M Moore     Teasley
# 2707   2/28/2022  3/18/2022                     Arnold Mill  Mill Creek
# 2708   3/14/2022  4/12/2022                     Arnold Mill  Mill Creek
# 2709   3/18/2022  4/18/2022                     Ball Ground   Creekland
# 2710   3/13/2022  4/13/2022                          Carmel   Woodstock
#
#         High Schl
# 0     River Ridge
# 1       Creekview
# 2       Creekview
# 3        Sequoyah
# 4        Sequoyah
# ...           ...
# 2706     Cherokee
# 2707  River Ridge
# 2708  River Ridge
# 2709    Creekview
# 2710    Woodstock
#
# [20335 rows x 27 columns]

# %%
master_data = pd.concat(df_list, ignore_index=True)
# master_data.tail()
master_data.to_csv('CountyMasterFile.csv')

# %%
master_data['High Schl'].unique()
# Out:
# array(['River Ridge', 'Creekview', 'Sequoyah', 'Cherokee', 'Woodstock',
#        'Etowah', 'Other'], dtype=object)
